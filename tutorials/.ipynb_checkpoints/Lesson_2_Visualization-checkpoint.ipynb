# %% [markdown]
# # VIZBI Tutorial Session
# ### Part 2: Cytoscape, IPython, Docker, and reproducible network data visualization workflows
#
# Tuesday, 3/24/2015
#
#
# ### Lesson 3: Reproducible Visualization Workflow
#
# by [Keiichiro Ono](http://keiono.github.io/)
#
# ----
#
# ![](http://cl.ly/aKS1/tca1.png)
#
#
# ## Background
# You can visualize network data set using easy-to-use Cytoscape GUI and you can save the final result as a ___session file___.  But if you need to create similar visualizations, you need to repeat the manual (point-and-click) operations again.  This will be more and more time consuming process as your data sets grows.  Good news is, you can avoid it by writing your visualization workflow as Notebooks!

# %%
import requests
import json
from IPython.display import Image
import pandas as pd

# Basic Setup
PORT_NUMBER = 1234
IP = '137.110.137.158' # Dont' forget to update this!!!!!!!!!!!!!!!
BASE = 'http://' + IP + ':' + str(PORT_NUMBER) + '/v1/'
HEADERS = {'Content-Type': 'application/json'}

# Utulity to POST object
def create(param, dict_data):
    return requests.post(BASE + param, data=json.dumps(dict_data), headers=HEADERS)

def update(param, dict_data):
    return requests.put(BASE + param, data=json.dumps(dict_data), headers=HEADERS)
    
# Start from a clean slate!
requests.delete(BASE + 'session')
# Out:
# <Response [200]>

# %% [markdown]
# ## Visual Style
#
# ![](http://cl.ly/aJam/visualstyles.png)
#
# To visuaize your data with Cytoscape, you need to understand its data-to-view mapping mechanism called ___Visual Style___.
#
# ### What is a Visual Style?
# __Visual Style is a collection of instructions how to map your data to visual properties (or visual variables)__.  To use it to make effective visualizations, you need to understand the following concepts.

# %%
# Get a list of all available Visual Styles
vs_url = BASE + 'styles'
res = requests.get(vs_url)
style_df = pd.DataFrame(res.json(), columns=['Style Name'])
style_df
# Out:
#   Style Name
# 0    default

# %% [markdown]
# #### Visual Properties
# Visual Properties, sometimes called [visual variables](http://www.infovis-wiki.net/index.php?title=Visual_Variables) in other applications, are properties of viewable objects, such as color, shape, opacity, size, etc.
#
# You can get the complete list of Visual Properties with the following code:

# %%
vps_url = BASE + 'styles/visualproperties'
print(vps_url)

# Let's make it a bit more human readable
res = requests.get(vps_url)
vp_df = pd.DataFrame(res.json(), columns=['visualProperty', 'name', 'targetDataType', 'default'])
vp_df.tail()
# Out:
# http://137.110.137.158:1234/v1/styles/visualproperties
#       visualProperty             name targetDataType default
# 98      NODE_VISIBLE     Node Visible         CyNode    true
# 99        NODE_WIDTH       Node Width         CyNode    60.0
# 100  NODE_X_LOCATION  Node X Location         CyNode     0.0
# 101  NODE_Y_LOCATION  Node Y Location         CyNode     0.0
# 102  NODE_Z_LOCATION  Node Z Location         CyNode     0.0

# %% [markdown]
# ##### Discrete Range Values
# Some of the Visual Properties have set of disrete values.  You can access those by _values_ API:

# %%
res = requests.get(vps_url + '/NODE_SHAPE/values')
node_shapes = pd.DataFrame(res.json()['values'], columns=['Node Shapes'])
node_shapes
# Out:
#        Node Shapes
# 0    PARALLELOGRAM
# 1  ROUND_RECTANGLE
# 2          OCTAGON
# 3         TRIANGLE
# 4          ELLIPSE
# 5          HEXAGON
# 6        RECTANGLE
# 7          DIAMOND
# 8              VEE

# %% [markdown]
# #### Defaults
# By default, there is no mapping from your data to Visual Properties.  __If there is no mapping for a Visual Property, default value will be used.__

# %%
directed_style_url = BASE + 'styles/default/defaults'
print(directed_style_url)

res = requests.get(directed_style_url)
defaults_df = pd.DataFrame(res.json()['defaults'], columns=['visualProperty', 'value'])
defaults_df.head()
# Out:
# http://137.110.137.158:1234/v1/styles/default/defaults
#          visualProperty            value
# 0             EDGE_BEND
# 1           EDGE_CURVED             True
# 2            EDGE_LABEL
# 3      EDGE_LABEL_COLOR          #000000
# 4  EDGE_LABEL_FONT_FACE  Dialog,plain,10

# %% [markdown]
# Let's try with actual network data.

# %%
# Load a network file
f = open('data/yeast.json', 'r')
cyjs_network = json.load(f)
cyjs_network['data']['name'] = 'Yeast 1' 

res = create('networks', cyjs_network)
suid = res.json()['networkSUID']

# Apply Visual Style "default"
requests.get(BASE + 'apply/styles/default')
requests.get(BASE + 'apply/layouts/degree-circle/' + str(suid))

paints = defaults_df[defaults_df['visualProperty'].str.contains('COLOR')]

paints.tail(10)
# Out:
#       visualProperty    value
# 3   EDGE_LABEL_COLOR  #000000
# 77   NODE_FILL_COLOR  #0099CC
# 80  NODE_LABEL_COLOR  #FFFFFF

# %%
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %%
# Let's change some default values.
new_values = [
    {
        'visualProperty':'NODE_FILL_COLOR',
        'value': '#7080BF'
    },
    {
        'visualProperty':'NODE_BORDER_WIDTH',
        'value': 0
    },
    {
        'visualProperty':'NODE_LABEL_FONT_SIZE',
        'value': 90
    },
    {
        'visualProperty':'NODE_WIDTH',
        'value': 60
    },
    {
        'visualProperty': 'EDGE_WIDTH',
        'value': 7
    },
    {
        'visualProperty': 'NODE_TRANSPARENCY',
        'value': 220
    },
    {
        'visualProperty': 'EDGE_TRANSPARENCY',
        'value': 200
    }
]

update('styles/default/defaults', new_values)
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %% [markdown]
# ### Excercise: Update default Values
# * Node Color
# * Edge Width
# * Node Shape

# %%
# Write your code here...

# %% [markdown]
# #### Mappings
# Mappings , or Visual Mapping Functions, are the actual mechanism to map data points to Visual Property values.  There are three types of mappings: discrete, continuous, and passthrough.

# %% [markdown]
# ##### Passthrough
# ___Passthrough Mapping___ is the simplest mapping mechanism in Cytoscape.  It simply map values to Visual Property.  For example, if you create a node name to node label mapping, it simply passes the node name text to the Mapping Function and displays as node label.

# %%
# Create a Passthrough mapping
new_passthrough_mapping = {
    'mappingType': 'passthrough',
    'mappingColumn': 'degree.layout',
    'mappingColumnType': 'Integer',
    'visualProperty': 'NODE_LABEL',
}

# Create a new style by POSTing the object
create('styles/default/mappings', [new_passthrough_mapping])
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %% [markdown]
# ##### Discrete
# Discrete mapping is the one maps discrete data points to any Visual Properties.  Here is the list of typical discrete mappings:
#
# * Node type (gene, protein complex, small compounds, etc.) to node shape
# * Node type to size
# * Interaction type (inhibition / activation) to arrow shape
# * Interaction detection method (Y2H, co-expression, text mining, etc.) to edge line style

# %%
# Create discrete mapping
new_disc_mapping = {
    'mappingType': 'discrete',
    'mappingColumn': 'interaction',
    'mappingColumnType': 'String',
    'visualProperty': 'EDGE_STROKE_UNSELECTED_PAINT',
    'map':[
        {
            'key': 'pp',
            'value': '#8899aa'
        },
        {
            'key': 'pd',
            'value': '#4876cc'
        }
    ]
}

line_style_mapping = {
    'mappingType': 'discrete',
    'mappingColumn': 'interaction',
    'mappingColumnType': 'String',
    'visualProperty': 'EDGE_LINE_STYLE',
    'map':[
        {
            'key': 'pp',
            'value': 'SOLID'
        },
        {
            'key': 'pd',
            'value': 'LONG_DASH'
        }
    ]
}

create('styles/default/mappings', [new_disc_mapping])
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %% [markdown]
# ##### Continuous

# %%
new_cont_mapping = {
    'mappingType': 'continuous',
    'mappingColumn': 'degree.layout',
    'mappingColumnType': 'Integer',
    'visualProperty': 'NODE_HEIGHT',
    'points':[
        {
            'value': 1,
            'lesser': '20',
            'equal': '20',
            'greater': '20'
        },
        {
            'value': 20,
            'lesser': '3000',
            'equal': '3000',
            'greater': '3000'
        }
    ]
}

new_color_mapping = {
    'mappingType': 'continuous',
    'mappingColumn': 'degree.layout',
    'mappingColumnType': 'Integer',
    'visualProperty': 'NODE_FILL_COLOR',
    'points':[
        {
            'value': 1,
            'lesser': '#EEEEEE',
            'equal': '#EEEEEE',
            'greater': '#EEEEEE'
        },
        {
            'value': 20,
            'lesser': '#333333',
            'equal': '#333333',
            'greater': '#333333'
        }
    ]
}
create('styles/default/mappings', [new_cont_mapping, new_color_mapping])
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %% [markdown]
# Now you can see the new mapping in the Cytoscape's Control Panel:
#
# ![](http://cl.ly/aKNs/cont_mapping1.png)

# %% [markdown]
# ### Apply Automatic Layout

# %%
# Apply force-directd layout
requests.get(BASE + 'apply/layouts/force-directed/' + str(suid))
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %% [markdown]
# ## Discussion
# OK, now you can create any mappings from Python.  But editing code like this manyally is a pain...
#
# ### _Don't repeat yourself!_
# The true power of __workflow-as-code__ is its reproducibility.  You can easily apply your existing code to other data sets.  The first step to reusability is writing common tasks as functions.

# %%
def get_basic_mapping(map_type, column, column_type, vp):
    new_mapping = {
         'mappingType': map_type,
        'mappingColumn': column,
        'mappingColumnType': column_type,
        'visualProperty': vp,
    }
    return new_mapping
    
def get_discrete_mapping(column, column_type, vp):
    mapping = get_basic_mapping('discrete', column, column_type, vp)
    mapping['map'] = []
    return mapping

def get_continuous_mapping(column, column_type, vp):
    mapping = get_basic_mapping('continuous', column, column_type, vp)
    mapping['points'] = []
    return mapping

def get_passthrough_mapping(column, column_type, vp):
    return get_basic_mapping('passthrough', column, column_type, vp)

# %% [markdown]
# And now you can do all kinds of crazy thing if you want...

# %%
# Find network ID
res = requests.get(BASE + 'networks/' + str(suid) + '/nodes')
node_suids = res.json()

import random

random_colors = []
for node in node_suids:
    entry = {
        'key': str(node),
        'value': '#' + format(random.randint(1,255), 'X') + format(random.randint(1,255), 'X') + format(random.randint(1,255), 'X')
    }
    random_colors.append(entry)
    
random_color_mapping = get_discrete_mapping('SUID', 'Long', 'NODE_FILL_COLOR')
random_color_mapping['map'] = random_colors

create('styles/default/mappings', [random_color_mapping])
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %% [markdown]
# And it is easy to reset it, by simply deleting the mapping.

# %%
res = requests.delete(BASE + 'styles/default/mappings/NODE_FILL_COLOR')
Image(BASE+'networks/' + str(suid) + '/views/first.png')

# %% [markdown]
# #### Is it worth wrting a new Python package?

# %% [markdown]
# ### Directly Set Visual Properties
# In general, Cytoscape visualizations are controlled by _Visual Styles_.  However, in some cases, you may want to edit the view directly.  Typical example is layout.  cyREST provides low level API to access View objects.  In this section, you will learn how to set view values through writing your own layout algorithm.
#
# ### Write your own layout algorithm
# You can move node (x,y) positions by setting new values for two Visual Properties:
# * __NODE_X_LOCATION__
# * __NODE_Y_LOCATION__
#
# The following is a simple example to arrange all nodes in one line.

# %%
# Find the Network View ID
res = requests.get(BASE + 'networks/' + str(suid) + '/views')
view_id = res.json()[0]
DISPLACEMENT = 64

def linear_layout(suid, node_list):
    # Node X Position = size
    position_list= []
    start_pos = 0
    for node in node_list:
        position = {
            'SUID': node,
            'view':[
                {
                    'visualProperty': 'NODE_X_LOCATION',
                    'value': start_pos
                },
                {
                    'visualProperty': 'NODE_Y_LOCATION',
                    'value': 0
                }
            ]
        }
        position_list.append(position)
        start_pos = start_pos + DISPLACEMENT
    return position_list
    

# Add edge bend information
bend = [
    {
        'visualProperty':'EDGE_BEND',
        'value': '0.5,-0.9,0.9'
    }
]
update('styles/default/defaults', bend)

posx = linear_layout(view_id, node_suids)
node_views_url = 'networks/' + str(suid) + '/views/' + str(view_id) + '/nodes'
res = update(node_views_url, posx)
requests.get(BASE + 'apply/fit/' + str(suid))

image_url = BASE+'networks/' + str(suid) + '/views/' + str(view_id) + '.png?h=700'
print(image_url)
res = requests.get(image_url)
Image(res.content)
# Out:
# http://137.110.137.158:1234/v1/networks/1176/views/1734.png?h=700

# %%
res = requests.get(BASE + 'networks/' + str(suid) + '/tables/defaultnode')
rows = res.json()['rows']
node_table_df = pd.DataFrame(rows)
node_table_df.head(10)
# Out:
#    SUID  degree_layout   id     name selected shared_name
# 0  1186              2  465  YIL162W    False     YIL162W
# 1  1187              2  469  YOR355W    False     YOR355W
# 2  1188              1  467  YFL038C    False     YFL038C
# 3  1189              1  477  YML123C    False     YML123C
# 4  1190              1  480  YHR071W    False     YHR071W
# 5  1191              2  479  YPL031C    False     YPL031C
# 6  1192              2  485  YDR009W    False     YDR009W
# 7  1193              4  483  YML051W    False     YML051W
# 8  1194              1  490  YML024W    False     YML024W
# 9  1195              2  488  YIL113W    False     YIL113W

# %%
sorted_nodes = node_table_df.sort_index(by=['degree_layout'])
sorted_nodes.tail(10)
# Out:
#      SUID  degree_layout   id     name selected shared_name
# 36   1222              7  388  YPL075W    False     YPL075W
# 156  1342              7  168  YDR412W    False     YDR412W
# 130  1316              7  196  YEL009C    False     YEL009C
# 202  1388              7  110  YJR022W    False     YJR022W
# 186  1372              8  660  YDR395W    False     YDR395W
# 120  1306              9  216  YLR362W    False     YLR362W
# 105  1291             11  231  YPL248C    False     YPL248C
# 101  1287             11  225  YGL035C    False     YGL035C
# 175  1361             17  128  YNL216W    False     YNL216W
# 67   1253             18  286  YMR043W    False     YMR043W

# %%
sorted_node_suids = sorted_nodes['SUID']
pos2 = sorted_node_suids.apply(lambda x: str(x))
posx = linear_layout(view_id, pos2.tolist())

res = update(node_views_url, posx)
requests.get(BASE + 'apply/fit/' + str(suid))

create('styles/default/mappings', [new_color_mapping])

image_url = BASE+'networks/' + str(suid) + '/views/' + str(view_id) + '.png?h=650'
print(image_url)
res = requests.get(image_url)

Image(res.content)
# Out:
# http://137.110.137.158:1234/v1/networks/1176/views/1734.png?h=650

# %% [markdown]
# ## Make it Interactive

# %%
import py2cytoscape.util as cy

# Package to render networks in Cytoscape.js
from py2cytoscape import cytoscapejs as cyjs

# Load local network files
current_view = requests.get(BASE + 'networks/3931/views/first')

default_style = requests.get(BASE + 'styles/KEGG Style.json')
cyjs_style = default_style.json()[0]['style']

# find Edge default values
for entry in cyjs_style:
    if entry['selector'] == 'node':
#         entry['css']['background-image'] = 'http://cl.ly/XohP/logo300.png'
#         entry['css']['background-fit'] = 'cover'
#         entry['css']['border-width'] =0
        print(json.dumps(entry, indent=4))
        break
# Out:
# {
#     "css": {
#         "font-weight": "normal",
#         "border-opacity": 1.0,
#         "width": "data(KEGG_NODE_WIDTH)",
#         "font-family": "HelveticaNeue",
#         "text-valign": "center",
#         "border-width": 0.0,
#         "background-color": "data(KEGG_NODE_FILL_COLOR)",
#         "shape": "ellipse",
#         "background-opacity": 0.9411764705882353,
#         "border-color": "rgb(0,0,0)",
#         "content": "data(KEGG_NODE_LABEL_LIST_FIRST)",
#         "font-size": 8,
#         "text-opacity": 1.0,
#         "color": "data(KEGG_NODE_LABEL_COLOR)",
#         "height": "data(KEGG_NODE_HEIGHT)",
#         "text-halign": "center"
#     },
#     "selector": "node"
# }

# %%
# Visualize it with Cytoscape.js
cyjs.render(current_view.json(), cyjs_style, 'preset')
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cy41324269-4ab8-43a2-b6db-06cea6bd270b {
#         height: 700px;
#         width: 1098px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background-color: #fafafa;
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cy41324269-4ab8-43a2-b6db-06cea6bd270b').cytoscape({
#             elements: {
#                 nodes: [{"selected": false, "data": {"name": "container", "id": "4160", "shared_name": "container", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_HEIGHT": "36", "selected": false, "KEGG_NODE_Y": "690", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_X": "1348", "KEGG_NODE_TYPE": "group", "KEGG_NODE_SHAPE": "rectangle", "SUID": 4160}, "position": {"y": 690.0, "x": 1348.0}}, {"selected": false, "data": {"name": "container", "id": "4159", "shared_name": "container", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_HEIGHT": "39", "selected": false, "KEGG_NODE_Y": "1124", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_X": "198", "KEGG_NODE_TYPE": "group", "KEGG_NODE_SHAPE": "rectangle", "SUID": 4159}, "position": {"y": 1124.0, "x": 198.0}}, {"selected": false, "data": {"name": "container", "id": "4158", "shared_name": "container", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_HEIGHT": "36", "selected": false, "KEGG_NODE_Y": "962", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_X": "237", "KEGG_NODE_TYPE": "group", "KEGG_NODE_SHAPE": "rectangle", "SUID": 4158}, "position": {"y": 962.0, "x": 237.0}}, {"selected": false, "data": {"name": "container", "id": "4157", "shared_name": "container", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_HEIGHT": "38", "selected": false, "KEGG_NODE_Y": "911", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_X": "684", "KEGG_NODE_TYPE": "group", "KEGG_NODE_SHAPE": "rectangle", "SUID": 4157}, "position": {"y": 911.0, "x": 684.0}}, {"selected": false, "data": {"name": "container", "id": "4156", "shared_name": "container", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_HEIGHT": "39", "selected": false, "KEGG_NODE_Y": "666", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_X": "590", "KEGG_NODE_TYPE": "group", "KEGG_NODE_SHAPE": "rectangle", "SUID": 4156}, "position": {"y": 666.0, "x": 590.0}}, {"selected": false, "data": {"name": "container", "id": "4155", "shared_name": "container", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_HEIGHT": "36", "selected": false, "KEGG_NODE_Y": "342", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_X": "294", "KEGG_NODE_TYPE": "group", "KEGG_NODE_SHAPE": "rectangle", "SUID": 4155}, "position": {"y": 342.0, "x": 294.0}}, {"selected": false, "data": {"name": "path:hsa05205:451", "id": "4154", "KEGG_NODE_LABEL": "KDR, CD309, FLK1, VEGFR, VEGFR2", "SUID": 4154, "KEGG_NODE_HEIGHT": "17", "KEGG_NODE_LABEL_COLOR": "#000000", "selected": false, "KEGG_NODE_Y": "1358", "KEGG_ID": ["hsa:3791"], "KEGG_NODE_FILL_COLOR": "#BFFFBF", "KEGG_NODE_LABEL_LIST_FIRST": "KDR", "KEGG_NODE_LABEL_LIST": ["KDR", "CD309", "FLK1", "VEGFR", "VEGFR2"], "KEGG_NODE_X": "894", "KEGG_NODE_TYPE": "gene", "shared_name": "path:hsa05205:451", "KEGG_NODE_SHAPE": "rectangle", "KEGG_LINK": "http://www.kegg.jp/dbget-bin/www_bget?hsa:3791", "KEGG_NODE_WIDTH": "46"}, "position": {"y": 1358.0, "x": 894.0}}, {"selected": false, "data": {"name": "path:hsa05205:449", "id": "4153", "KEGG_NODE_LABEL": "C00925", "SUID": 4153, "KEGG_NODE_HEIGHT": "8", "KEGG_NODE_LABEL_COLOR": "#000000", "selected": false, "KEGG_NODE_Y": "600", "KEGG_ID": ["cpd:C00925"], "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_LABEL_LIST_FIRST": "Heparan sulfate", "KEGG_NODE_LABEL_LIST": ["C00925"], "KEGG_NODE_X": "1121", "KEGG_NODE_TYPE": "compound", "shared_name": "path:hsa05205:449", "KEGG_NODE_SHAPE": "circle", "KEGG_LINK": "http://www.kegg.jp/dbget-bin/www_bget?C00925", "KEGG_NODE_WIDTH": "8"}, "position": {"y": 600.0, "x": 1121.0}}, {"selected": false, "data": {"name": "path:hsa05205:448", "id": "4152", "KEGG_NODE_LABEL": "C00925", "SUID": 4152, "KEGG_NODE_HEIGHT": "8", "KEGG_NODE_LABEL_COLOR": "#000000", "selected": false, "KEGG_NODE_Y": "463", "KEGG_ID": ["cpd:C00925"], "KEGG_NODE_FILL_COLOR": "#FFFFFF", "KEGG_NODE_LABEL_LIST_FIRST": "Heparan sulfate", "KEGG_NODE_LABEL_LIST": ["C00925"], "KEGG_NODE_X": "1122", "KEGG_NODE_TYPE": "compound", "shared_name": "path:hsa05205:448", "KEGG_NODE_SHAPE": "circle", "KEGG_LINK": "http://www.kegg.jp/dbget-bin/www_bget?C00925", "KEGG_NODE_WIDTH": "8"}, "position": {"y": ...

# %%
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cyb0d49862-f42b-453f-af33-ac78465621b9 {
#         height: 700px;
#         width: 1098px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background-color: #fafafa;
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cyb0d49862-f42b-453f-af33-ac78465621b9').cytoscape({
#             elements: {
#                 nodes: [{"selected": false, "data": {"name": "YBR135W", "id": "533", "shared_name": "YBR135W", "SUID": 1434, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 8064.0}}, {"selected": false, "data": {"name": "YNL117W", "id": "541", "shared_name": "YNL117W", "SUID": 1433, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 1152.0}}, {"selected": false, "data": {"name": "YOR089C", "id": "539", "shared_name": "YOR089C", "SUID": 1432, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 3712.0}}, {"selected": false, "data": {"name": "YPR167C", "id": "537", "shared_name": "YPR167C", "SUID": 1431, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 3456.0}}, {"selected": false, "data": {"name": "YLR432W", "id": "546", "shared_name": "YLR432W", "SUID": 1430, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6720.0}}, {"selected": false, "data": {"name": "YDR167W", "id": "545", "shared_name": "YDR167W", "SUID": 1429, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6656.0}}, {"selected": false, "data": {"name": "YLR175W", "id": "543", "shared_name": "YLR175W", "SUID": 1428, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 3200.0}}, {"selected": false, "data": {"name": "YDR354W", "id": "502", "shared_name": "YDR354W", "SUID": 1427, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 3072.0}}, {"selected": false, "data": {"name": "YDR146C", "id": "496", "shared_name": "YDR146C", "SUID": 1426, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6592.0}}, {"selected": false, "data": {"name": "YER103W", "id": "507", "shared_name": "YER103W", "SUID": 1425, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6528.0}}, {"selected": false, "data": {"name": "YOL059W", "id": "515", "shared_name": "YOL059W", "SUID": 1424, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 2880.0}}, {"selected": false, "data": {"name": "YER102W", "id": "517", "shared_name": "YER102W", "SUID": 1423, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6464.0}}, {"selected": false, "data": {"name": "YBR190W", "id": "513", "shared_name": "YBR190W", "SUID": 1422, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 2624.0}}, {"selected": false, "data": {"name": "YOL149W", "id": "523", "shared_name": "YOL149W", "SUID": 1421, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6400.0}}, {"selected": false, "data": {"name": "YOR362C", "id": "519", "shared_name": "YOR362C", "SUID": 1420, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 2688.0}}, {"selected": false, "data": {"name": "YMR044W", "id": "521", "shared_name": "YMR044W", "SUID": 1419, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 4928.0}}, {"selected": false, "data": {"name": "YER052C", "id": "591", "shared_name": "YER052C", "SUID": 1418, "degree_layout": 1, "selected": false}, "position": {"y": 0.0, "x": 4864.0}}, {"selected": false, "data": {"name": "YNL135C", "id": "592", "shared_name": "YNL135C", "SUID": 1417, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6784.0}}, {"selected": false, "data": {"name": "YHR055C", "id": "598", "shared_name": "YHR055C", "SUID": 1416, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6336.0}}, {"selected": false, "data": {"name": "YHR053C", "id": "596", "shared_name": "YHR053C", "SUID": 1415, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6208.0}}, {"selected": false, "data": {"name": "YLR258W", "id": "602", "shared_name": "YLR258W", "SUID": 1414, "degree_layout": 3, "selected": false}, "position": {"y": 0.0, "x": 11904.0}}, {"selected": false, "data": {"name": "YGL134W", "id": "600", "shared_name": "YGL134W", "SUID": 1413, "degree_layout": 2, "selected": false}, "position": {"y": 0.0, "x": 6144.0}}, {"selected": false, "data": {"name":  ...

# %% [markdown]
# ## Save the final result as a _Session File_
# And now you can save the entire process as Notebooks, and the result as ___Session File___.

# %%
session_file_name = {
    'file': '/Users/kono/Desktop/yeast_session.cys'
}
res = requests.post(BASE + 'session',  params=session_file_name, data=None, headers=HEADERS)
print(json.dumps(res.json(), indent=4))
# Out:
# {
#     "file": "/Users/kono/Desktop/yeast_session.cys"
# }

# %% [markdown]
# ## Summary
# All of the visualizations you created here are reproducible, only with one click (___Run All___ under _Cell_ menu).  In addition, you can reuse the code segments here to make more effective, realistic data visualizations.
